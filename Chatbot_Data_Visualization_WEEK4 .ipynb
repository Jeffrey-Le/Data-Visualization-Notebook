# %%
import numpy as np
import pandas as pd

import re, nltk

import string

import ssl
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

from collections import Counter

from textblob import TextBlob
from spellchecker import SpellChecker

# %%
df = pd.read_csv('C:/Users/Crolw/Downloads/twcs.csv')

# %% [markdown]
# ## Change Datatypes to correct type
# #### author_id: object -> string
# #### text: object -> string
# #### created_at: object -> string

# %%
df['author_id'] = df['author_id'].astype('string')
df['text'] = df['text'].astype('string')
df['created_at'] = pd.to_datetime(df['created_at']).dt.strftime('%Y-%m-%d').astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2811774 entries, 0 to 2811773
# Data columns (total 7 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tweet_id                 int64
#  1   author_id                object
#  2   inbound                  bool
#  3   created_at               object
#  4   text                     object
#  5   response_tweet_id        object
#  6   in_response_to_tweet_id  float64
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 131.4+ MB

# %%
df.isna().any()
# Out:
# tweet_id                   False
# author_id                  False
# inbound                    False
# created_at                 False
# text                       False
# response_tweet_id           True
# in_response_to_tweet_id     True
# dtype: bool

# %% [markdown]
# ### Text Cleaning
#
# #### Make new variable to focus on text data

# %%
# Since we are only interested in text the part for now
textDF = df[['text']]
print('shape is:', textDF.shape)
textDF.head()
# Out:
# shape is: (2811774, 1)
#                                                 text
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.

# %% [markdown]
# #### Make new column to convert text into only lowercase

# %%
textDF['text_lower'] = textDF.loc[:,'text'].str.lower()
textDF.head(10)
# Out:
# C:\Users\Crolw\AppData\Local\Temp\ipykernel_22752\816064500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   textDF['text_lower'] = textDF.loc[:,'text'].str.lower()
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
# 5  @115712 Can you please send us a private messa...
# 6          @sprintcare is the worst customer service
# 7  @115713 This is saddening to hear. Please shoo...
# 8  @sprintcare You gonna magically change your co...
# 9  @115713 We understand your concerns and we'd l...
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
# 5  @115712 can you please send us a private messa...
# 6          @sprintcare is the worst customer service
# 7  @115713 this is saddening to hear. please shoo...
# 8  @sprintcare you gonna magically change your co...
# 9  @115713 we understand your concerns and we'd l...

# %% [markdown]
# #### Make new column with no puncuations

# %%
punctuations = string.punctuation
print(punctuations)

# %timeit
def remove_punctuations(text):
    return text.translate(str.maketrans('','',punctuations))
    

textDF['text_wo_punct'] = textDF['text_lower'].apply(lambda text: remove_punctuations(text))
textDF.head(10)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# C:\Users\Crolw\AppData\Local\Temp\ipykernel_22752\438778996.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   textDF['text_wo_punct'] = textDF['text_lower'].apply(lambda text: remove_punctuations(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
# 5  @115712 Can you please send us a private messa...
# 6          @sprintcare is the worst customer service
# 7  @115713 This is saddening to hear. Please shoo...
# 8  @sprintcare You gonna magically change your co...
# 9  @115713 We understand your concerns and we'd l...
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
# 5  @115712 can you please send us a private messa...
# 6          @sprintcare is the worst customer service
# 7  @115713 this is saddening to hear. please shoo...
# 8  @sprintcare you gonna magically change your co...
# 9  @115713 we understand your concerns and we'd l...
#
#                                        text_wo_punct
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# 4                                   sprintcare i did
# 5  115712 can you please send us a private messag...
# 6           sprintcare is the worst customer service
# 7  115713 this is saddening to hear please shoot ...
# 8  sprintcare you gonna magically change your con...
# 9  115713 we understand your concerns and wed lik...

# %%
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Crolw\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Crolw\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Crolw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# #### Load stopwords

# %%
', '.join(stopwords.words('english'))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't"

# %% [markdown]
# #### Make new column that eliminates stopwords

# %%
stopwords_set = set(stopwords.words('english'))
def remove_stopwords(text):
    return ' '.join(words for words in str(text).split() if words not in stopwords_set)
    

textDF['text_wo_stop'] = textDF['text_wo_punct'].apply(lambda text: remove_stopwords(text))
textDF.head()
# Out:
# C:\Users\Crolw\AppData\Local\Temp\ipykernel_22752\1961305086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   textDF['text_wo_stop'] = textDF['text_wo_punct'].apply(lambda text: remove_stopwords(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                        text_wo_punct  \
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# 4                                   sprintcare i did
#
#                                         text_wo_stop
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist c...
# 4                                         sprintcare

# %% [markdown]
# #### Count most used words

# %%
cnt = Counter()

for text in textDF['text_wo_stop'].values:
    for word in text.split():
        cnt[word] +=1
        
cnt.most_common(10)
# Out:
# [('us', 451262),
#  ('please', 402709),
#  ('dm', 335374),
#  ('help', 267633),
#  ('hi', 224603),
#  ('thanks', 206452),
#  ('get', 200374),
#  ('sorry', 192246),
#  ('like', 146385),
#  ('know', 145407)]

# %% [markdown]
# #### Make new column with frequently used words eliminated

# %%
freq_words = set([w for (w,wc) in cnt.most_common(10)])

def remove_freqwords(text):
    return ' '.join(word for word in str(text).split() if word not in freq_words)

textDF['text_wo_freq'] = textDF['text_wo_stop'].apply(lambda text:remove_freqwords(text))
textDF.head()
# Out:
# C:\Users\Crolw\AppData\Local\Temp\ipykernel_22752\3239245677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   textDF['text_wo_freq'] = textDF['text_wo_stop'].apply(lambda text:remove_freqwords(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                        text_wo_punct  \
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# 4                                   sprintcare i did
#
#                                         text_wo_stop  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist c...
# 4                                         sprintcare
#
#                                         text_wo_freq
# 0  115712 understand would assist would need priv...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                         sprintcare

# %% [markdown]
# #### Make new column with rare words eliminated

# %%
n_rare_words = 10
rare_words = set([w for (w,c) in cnt.most_common()][:- n_rare_words: -1])
print(rare_words)

def remove_rarewords(text):
    return ' '.join(word for word in str(text).split() if word not in rare_words)

textDF['text_wo_freqrare'] = textDF['text_wo_freq'].apply(lambda text:remove_rarewords(text))
textDF.head()
# Out:
# {'823868', 'notjustxmasallyearround', '823869', 'httpstco4v1ft0th5x', 'httpstco7uqpwyh1b6', 'httpstcov2tmhetl7q', '823867', '823870', 'httpstcogfyuq1kjtk'}
# C:\Users\Crolw\AppData\Local\Temp\ipykernel_22752\1870184822.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   textDF['text_wo_freqrare'] = textDF['text_wo_freq'].apply(lambda text:remove_rarewords(text))
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                        text_wo_punct  \
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# 4                                   sprintcare i did
#
#                                         text_wo_stop  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist c...
# 4                                         sprintcare
#
#                                         text_wo_freq  \
# 0  115712 understand would assist would need priv...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                         sprintcare
#
#                                     text_wo_freqrare
# 0  115712 understand would assist would need priv...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                         sprintcare

# %% [markdown]
# #### Stemming

# %%
stemmer = PorterStemmer()

# %%
# Stem every word
textDF['text_stemmed'] = textDF['text_wo_freqrare'].apply(lambda text: ' '.join([stemmer.stem(word) for word in text.split()]))

# %%
textDF.head(10)
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
# 5  @115712 Can you please send us a private messa...
# 6          @sprintcare is the worst customer service
# 7  @115713 This is saddening to hear. Please shoo...
# 8  @sprintcare You gonna magically change your co...
# 9  @115713 We understand your concerns and we'd l...
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
# 5  @115712 can you please send us a private messa...
# 6          @sprintcare is the worst customer service
# 7  @115713 this is saddening to hear. please shoo...
# 8  @sprintcare you gonna magically change your co...
# 9  @115713 we understand your concerns and we'd l...
#
#                                        text_wo_punct  \
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# 4                                   sprintcare i did
# 5  115712 can you please send us a private messag...
# 6           sprintcare is the worst customer service
# 7  115713 this is saddening to hear please shoot ...
# 8  sprintcare you gonna magically change your con...
# 9  115713 we understand your concerns and wed lik...
#
#                                         text_wo_stop  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist c...
# 4                                         sprintcare
# 5  115712 please send us private message gain det...
# 6                  sprintcare worst customer service
# 7   115713 saddening hear please shoot us dm look kc
# 8  sprintcare gonna magically change connectivity...
# 9  115713 understand concerns wed like please sen...
#
#                                         text_wo_freq  \
# 0  115712 understand would assist would need priv...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                         sprintcare
# 5   115712 send private message gain details account
# 6                  sprintcare worst customer service
# 7                115713 saddening hear shoot look kc
# 8  sprintcare gonna magically change connectivity...
# 9  115713 understand concerns wed send direct mes...
#
#                                     text_wo_freqrare  \
# 0  115712 understand would assist would need priv...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                         sprintcare
# 5   115712 send private message gain details account
# 6                  sprintcare worst customer service
# 7                115713 saddening hear shoot look kc
# 8  sprintcare gonna magically change connectivity...
# 9  115713 understand concerns wed send direct mes...
#
#                                         text_stemmed
# 0  115712 understand would assist would need priv...
# 1                                   sprintcar propos
# 2  sprintcar sent sever privat messag one respond...
# 3  115712 send privat messag assist click ‘messag...
# 4                                          sprintcar
# 5      115712 send privat messag gain detail account
# 6                      sprintcar worst custom servic
# 7                   115713 sadden hear shoot look kc
# 8  sprintcar gonna magic chang connect whole fami...
# 9  115713 understand concern wed send direct mess...

# %% [markdown]
# #### Lemmatization

# %%
lemmatizer = WordNetLemmatizer()

# %%
# Lemmanize every word
textDF['text_lemmatized'] = textDF['text_wo_freqrare'].apply(lambda text: ' '.join([lemmatizer.lemmatize(word) for word in text.split()]))

# %%
textDF.head(10)
# Out:
#                                                 text  \
# 0  @115712 I understand. I would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
# 5  @115712 Can you please send us a private messa...
# 6          @sprintcare is the worst customer service
# 7  @115713 This is saddening to hear. Please shoo...
# 8  @sprintcare You gonna magically change your co...
# 9  @115713 We understand your concerns and we'd l...
#
#                                           text_lower  \
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
# 5  @115712 can you please send us a private messa...
# 6          @sprintcare is the worst customer service
# 7  @115713 this is saddening to hear. please shoo...
# 8  @sprintcare you gonna magically change your co...
# 9  @115713 we understand your concerns and we'd l...
#
#                                        text_wo_punct  \
# 0  115712 i understand i would like to assist you...
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# 4                                   sprintcare i did
# 5  115712 can you please send us a private messag...
# 6           sprintcare is the worst customer service
# 7  115713 this is saddening to hear please shoot ...
# 8  sprintcare you gonna magically change your con...
# 9  115713 we understand your concerns and wed lik...
#
#                                         text_wo_stop  \
# 0  115712 understand would like assist would need...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 please send us private message assist c...
# 4                                         sprintcare
# 5  115712 please send us private message gain det...
# 6                  sprintcare worst customer service
# 7   115713 saddening hear please shoot us dm look kc
# 8  sprintcare gonna magically change connectivity...
# 9  115713 understand concerns wed like please sen...
#
#                                         text_wo_freq  \
# 0  115712 understand would assist would need priv...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                         sprintcare
# 5   115712 send private message gain details account
# 6                  sprintcare worst customer service
# 7                115713 saddening hear shoot look kc
# 8  sprintcare gonna magically change connectivity...
# 9  115713 understand concerns wed send direct mes...
#
#                                     text_wo_freqrare  \
# 0  115712 understand would assist would need priv...
# 1                                 sprintcare propose
# 2  sprintcare sent several private messages one r...
# 3  115712 send private message assist click ‘mess...
# 4                                         sprintcare
# 5   115712 send private message gain details account
# 6                  sprintcare worst customer service
# 7                115713 saddening hear shoot look kc
# 8  sprintcare gonna magically change connectivity...
# 9  115713 understand concerns wed send direct mes...
#
#                                         text_stemmed  \
# 0  115712 understand would assist would need priv...
# 1                                   sprintcar propos
# 2  sprintcar sent sever privat messag one respond...
# 3  115712 send privat messag assist click ‘messag...
# 4                                          sprintcar
# 5      115712 send privat messag gain detail account
# 6                      sprintcar worst custom servic
# 7                   115713 sadden hear shoot look kc
# 8  sprintcar gonna magic chang connect whole fami...
# 9  115713 understand concern wed send direct mess...
#
#                                      text_lemmatized
# 0  115712 understand would assist would need priv...
# 1                                 sprintcare propose
# 2  sprintcare sent several private message one re...
# 3  115712 send private message assist click ‘mess...
# 4                                         sprintcare
# 5    115712 send private message gain detail account
# 6                  sprintcare worst customer service
# 7                115713 saddening hear shoot look kc
# 8  sprintcare gonna magically change connectivity...
# 9  115713 understand concern wed send direct mess...

# %% [markdown]
# #### Removal of Emojis and Emoticons

# %%
emojiPattern = re.compile("["u"\U0001F600-\U0001F64F""]+", flags=re.UNICODE)

# %%
textDF['text_wo_emoticons'] = textDF['text_lemmatized'].apply(lambda text: emojiPattern.sub(r'', text))
textDF.tail(10)
# Out:
#                                                       text  \
# 2811764  @823868 Sorry but kindly try to clear browser,...
# 2811765  @AirAsiaSupport \n\nI am unable to do web chec...
# 2811766  @134664 Can you Dm us your order number and we...
# 2811767  @524544 That's a Peak service. The 09:56 is th...
# 2811768  @VirginTrains Hope you are well? Does the 9.30...
# 2811769  @823869 Hey, we'd be happy to look into this f...
# 2811770  @115714 wtf!? I’ve been having really shitty s...
# 2811771  @143549 @sprintcare You have to go to https://...
# 2811772  @823870 Sounds delicious, Sarah! 😋 https://t.c...
# 2811773  @AldiUK  warm sloe gin mince pies with ice cre...
#
#                                                 text_lower  \
# 2811764  @823868 sorry but kindly try to clear browser,...
# 2811765  @airasiasupport \n\ni am unable to do web chec...
# 2811766  @134664 can you dm us your order number and we...
# 2811767  @524544 that's a peak service. the 09:56 is th...
# 2811768  @virgintrains hope you are well? does the 9.30...
# 2811769  @823869 hey, we'd be happy to look into this f...
# 2811770  @115714 wtf!? i’ve been having really shitty s...
# 2811771  @143549 @sprintcare you have to go to https://...
# 2811772  @823870 sounds delicious, sarah! 😋 https://t.c...
# 2811773  @aldiuk  warm sloe gin mince pies with ice cre...
#
#                                              text_wo_punct  \
# 2811764  823868 sorry but kindly try to clear browserca...
# 2811765  airasiasupport \n\ni am unable to do web check...
# 2811766  134664 can you dm us your order number and we ...
# 2811767  524544 thats a peak service the 0956 is the fi...
# 2811768  virgintrains hope you are well does the 930am ...
# 2811769  823869 hey wed be happy to look into this for ...
# 2811770  115714 wtf i’ve been having really shitty serv...
# 2811771  143549 sprintcare you have to go to httpstcov2...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk  warm sloe gin mince pies with ice crea...
#
#                                               text_wo_stop  \
# 2811764  823868 sorry kindly try clear browsercachecook...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766             134664 dm us order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769  823869 hey wed happy look please send us direc...
# 2811770  115714 wtf i’ve really shitty service day get ...
# 2811771  143549 sprintcare go httpstcov2tmhetl7q ask ad...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                               text_wo_freq  \
# 2811764  823868 kindly try clear browsercachecookies tr...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769  823869 hey wed happy look send direct message ...
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go httpstcov2tmhetl7q ask ad...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                           text_wo_freqrare  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                           sounds delicious sarah 😋
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                               text_stemmed  \
# 2811764  kindli tri clear browsercachecooki tri work fi...
# 2811765  airasiasupport unabl web checkin get error che...
# 2811766                   134664 order number look georgia
# 2811767  524544 that peak servic 0956 first offpeak tra...
# 2811768  virgintrain hope well 930am train crew euston ...
# 2811769    hey wed happi look send direct messag assist tn
# 2811770  115714 wtf i’v realli shitti servic day shit t...
# 2811771  143549 sprintcar go ask add hulu servic accoun...
# 2811772                               sound delici sarah 😋
# 2811773  aldiuk warm sloe gin minc pie ice cream best t...
#
#                                            text_lemmatized  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                            sound delicious sarah 😋
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...
#
#                                          text_wo_emoticons
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                             sound delicious sarah
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...

# %% [markdown]
# #### Conversion of Emoticons and Emojis to Words

# %% [markdown]
# #### Removal of URLs

# %%
textDF["text_wo_url"] = textDF["text_wo_emoticons"].str.replace(r'\s*https?://\S+(\s+|$)', ' ').str.strip()
textDF.tail(10)
# Out:
# C:\Users\Crolw\AppData\Local\Temp\ipykernel_22752\4144346981.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   textDF["text_wo_url"] = textDF["text_wo_emoticons"].str.replace(r'\s*https?://\S+(\s+|$)', ' ').str.strip()
#                                                       text  \
# 2811764  @823868 Sorry but kindly try to clear browser,...
# 2811765  @AirAsiaSupport \n\nI am unable to do web chec...
# 2811766  @134664 Can you Dm us your order number and we...
# 2811767  @524544 That's a Peak service. The 09:56 is th...
# 2811768  @VirginTrains Hope you are well? Does the 9.30...
# 2811769  @823869 Hey, we'd be happy to look into this f...
# 2811770  @115714 wtf!? I’ve been having really shitty s...
# 2811771  @143549 @sprintcare You have to go to https://...
# 2811772  @823870 Sounds delicious, Sarah! 😋 https://t.c...
# 2811773  @AldiUK  warm sloe gin mince pies with ice cre...
#
#                                                 text_lower  \
# 2811764  @823868 sorry but kindly try to clear browser,...
# 2811765  @airasiasupport \n\ni am unable to do web chec...
# 2811766  @134664 can you dm us your order number and we...
# 2811767  @524544 that's a peak service. the 09:56 is th...
# 2811768  @virgintrains hope you are well? does the 9.30...
# 2811769  @823869 hey, we'd be happy to look into this f...
# 2811770  @115714 wtf!? i’ve been having really shitty s...
# 2811771  @143549 @sprintcare you have to go to https://...
# 2811772  @823870 sounds delicious, sarah! 😋 https://t.c...
# 2811773  @aldiuk  warm sloe gin mince pies with ice cre...
#
#                                              text_wo_punct  \
# 2811764  823868 sorry but kindly try to clear browserca...
# 2811765  airasiasupport \n\ni am unable to do web check...
# 2811766  134664 can you dm us your order number and we ...
# 2811767  524544 thats a peak service the 0956 is the fi...
# 2811768  virgintrains hope you are well does the 930am ...
# 2811769  823869 hey wed be happy to look into this for ...
# 2811770  115714 wtf i’ve been having really shitty serv...
# 2811771  143549 sprintcare you have to go to httpstcov2...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk  warm sloe gin mince pies with ice crea...
#
#                                               text_wo_stop  \
# 2811764  823868 sorry kindly try clear browsercachecook...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766             134664 dm us order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769  823869 hey wed happy look please send us direc...
# 2811770  115714 wtf i’ve really shitty service day get ...
# 2811771  143549 sprintcare go httpstcov2tmhetl7q ask ad...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                               text_wo_freq  \
# 2811764  823868 kindly try clear browsercachecookies tr...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769  823869 hey wed happy look send direct message ...
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go httpstcov2tmhetl7q ask ad...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                           text_wo_freqrare  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                           sounds delicious sarah 😋
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                               text_stemmed  \
# 2811764  kindli tri clear browsercachecooki tri work fi...
# 2811765  airasiasupport unabl web checkin get error che...
# 2811766                   134664 order number look georgia
# 2811767  524544 that peak servic 0956 first offpeak tra...
# 2811768  virgintrain hope well 930am train crew euston ...
# 2811769    hey wed happi look send direct messag assist tn
# 2811770  115714 wtf i’v realli shitti servic day shit t...
# 2811771  143549 sprintcar go ask add hulu servic accoun...
# 2811772                               sound delici sarah 😋
# 2811773  aldiuk warm sloe gin minc pie ice cream best t...
#
#                                            text_lemmatized  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                            sound delicious sarah 😋
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...
#
#                                          text_wo_emoticons  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                             sound delicious sarah
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...
#
#                                                text_wo_url
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                              sound delicious sarah
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...

# %% [markdown]
# #### Removal of HTML Tags

# %%
textDF['text_wo_tags'] = textDF['text_wo_url'].apply(lambda text: ' '.join([re.sub('<.*?>','', text)]))
textDF.tail(10)
# Out:
#                                                       text  \
# 2811764  @823868 Sorry but kindly try to clear browser,...
# 2811765  @AirAsiaSupport \n\nI am unable to do web chec...
# 2811766  @134664 Can you Dm us your order number and we...
# 2811767  @524544 That's a Peak service. The 09:56 is th...
# 2811768  @VirginTrains Hope you are well? Does the 9.30...
# 2811769  @823869 Hey, we'd be happy to look into this f...
# 2811770  @115714 wtf!? I’ve been having really shitty s...
# 2811771  @143549 @sprintcare You have to go to https://...
# 2811772  @823870 Sounds delicious, Sarah! 😋 https://t.c...
# 2811773  @AldiUK  warm sloe gin mince pies with ice cre...
#
#                                                 text_lower  \
# 2811764  @823868 sorry but kindly try to clear browser,...
# 2811765  @airasiasupport \n\ni am unable to do web chec...
# 2811766  @134664 can you dm us your order number and we...
# 2811767  @524544 that's a peak service. the 09:56 is th...
# 2811768  @virgintrains hope you are well? does the 9.30...
# 2811769  @823869 hey, we'd be happy to look into this f...
# 2811770  @115714 wtf!? i’ve been having really shitty s...
# 2811771  @143549 @sprintcare you have to go to https://...
# 2811772  @823870 sounds delicious, sarah! 😋 https://t.c...
# 2811773  @aldiuk  warm sloe gin mince pies with ice cre...
#
#                                              text_wo_punct  \
# 2811764  823868 sorry but kindly try to clear browserca...
# 2811765  airasiasupport \n\ni am unable to do web check...
# 2811766  134664 can you dm us your order number and we ...
# 2811767  524544 thats a peak service the 0956 is the fi...
# 2811768  virgintrains hope you are well does the 930am ...
# 2811769  823869 hey wed be happy to look into this for ...
# 2811770  115714 wtf i’ve been having really shitty serv...
# 2811771  143549 sprintcare you have to go to httpstcov2...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk  warm sloe gin mince pies with ice crea...
#
#                                               text_wo_stop  \
# 2811764  823868 sorry kindly try clear browsercachecook...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766             134664 dm us order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769  823869 hey wed happy look please send us direc...
# 2811770  115714 wtf i’ve really shitty service day get ...
# 2811771  143549 sprintcare go httpstcov2tmhetl7q ask ad...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                               text_wo_freq  \
# 2811764  823868 kindly try clear browsercachecookies tr...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769  823869 hey wed happy look send direct message ...
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go httpstcov2tmhetl7q ask ad...
# 2811772  823870 sounds delicious sarah 😋 httpstco7uqpwy...
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                           text_wo_freqrare  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                           sounds delicious sarah 😋
# 2811773  aldiuk warm sloe gin mince pies ice cream best...
#
#                                               text_stemmed  \
# 2811764  kindli tri clear browsercachecooki tri work fi...
# 2811765  airasiasupport unabl web checkin get error che...
# 2811766                   134664 order number look georgia
# 2811767  524544 that peak servic 0956 first offpeak tra...
# 2811768  virgintrain hope well 930am train crew euston ...
# 2811769    hey wed happi look send direct messag assist tn
# 2811770  115714 wtf i’v realli shitti servic day shit t...
# 2811771  143549 sprintcar go ask add hulu servic accoun...
# 2811772                               sound delici sarah 😋
# 2811773  aldiuk warm sloe gin minc pie ice cream best t...
#
#                                            text_lemmatized  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                            sound delicious sarah 😋
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...
#
#                                          text_wo_emoticons  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                             sound delicious sarah
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...
#
#                                                text_wo_url  \
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                              sound delicious sarah
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...
#
#                                               text_wo_tags
# 2811764  kindly try clear browsercachecookies try worki...
# 2811765  airasiasupport unable web checkin getting erro...
# 2811766                   134664 order number look georgia
# 2811767  524544 thats peak service 0956 first offpeak t...
# 2811768  virgintrains hope well 930am train crewe eusto...
# 2811769   hey wed happy look send direct message assist tn
# 2811770  115714 wtf i’ve really shitty service day shit...
# 2811771  143549 sprintcare go ask add hulu service acco...
# 2811772                              sound delicious sarah
# 2811773  aldiuk warm sloe gin mince pie ice cream best ...

# %% [markdown]
# #### Chat Words Conversion

# %% [markdown]
# #### Spelling Correction

# %%
textDF['text_correction'] = textDF['text_wo_tags'].apply(lambda text: ' '.join([str(SpellChecker().correction(word)) for word in word_tokenize(text)]))

# %%
textDF.head(10)

# %% [markdown]
# ### Data Wrangling

# %%
first_inbound = df[pd.isnull(df.in_response_to_tweet_id) & df.inbound]

QnR = pd.merge(first_inbound, df, left_on='tweet_id', 
                                  right_on='in_response_to_tweet_id')

# Filter to only outbound replies (from companies)
QnR = QnR[QnR.inbound_y ^ True]
print(f'Data shape: {QnR.shape}')
QnR.head()
